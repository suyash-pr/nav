# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"/data/model-training/lidar2d_front_left/lidar2d_front_left_points.csv", delimiter=";")

# %%
len(df['timestamp_us'].unique()), len(df)
# Out:
# (112846, 112846)
